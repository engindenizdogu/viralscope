# %%
''' Dataset information
| Data File                   | Size     | Comment                                    |
|:----------------------------|:---------|:-------------------------------------------|
| _raw_df_channels.tsv.gz     | 6.4 MB   | Sample dataset created.                    |
| _raw_df_timeseries.tsv.gz   | 653.1 MB | Sample dataset created.                    |
| _raw_yt_metadata.jsonl.zst  | 14.7 GB  | See 'create_sample_datasets_json.ipynb'    |
| df_channels_en.tsv.gz       | 6.0 MB   | Sample dataset created.                    |
| df_timeseries_en.tsv.gz     | 571.1 MB | Sample dataset created.                    |
| num_comments.tsv.gz         | 754.6 MB | Sample dataset created.                    |
| num_comments_authors.tsv.gz | 1.4 GB   | Sample dataset created.                    |
| youtube_comments.tsv.gz     | 77.2 GB  | Downloading...                             |
| yt_metadata_en.jsonl.gz     | 13.6 GB  | See 'create_sample_datasets_json.ipynb'    |
| yt_metadata_helper.feather  | 2.8 GB   | See 'create_sample_datasets_feather.ipynb' |
'''
# Out:
# ' Dataset information\n| Data File                   | Size     | Comment                 |\n|:----------------------------|:---------|:------------------------|\n| _raw_df_channels.tsv.gz     | 6.4 MB   | Sample dataset created. |\n| _raw_df_timeseries.tsv.gz   | 653.1 MB | Sample dataset created. |\n| _raw_yt_metadata.jsonl.zst  | 14.7 GB  | Downloading...          |\n| df_channels_en.tsv.gz       | 6.0 MB   | Sample dataset created. |\n| df_timeseries_en.tsv.gz     | 571.1 MB | Sample dataset created. |\n| num_comments.tsv.gz         | 754.6 MB | Sample dataset created. |\n| num_comments_authors.tsv.gz | 1.4 GB   | Sample dataset created. |\n| youtube_comments.tsv.gz     | 77.2 GB  | Downloading...          |\n| yt_metadata_en.jsonl.gz     | 13.6 GB  | Downloading...          |\n| yt_metadata_helper.feather  | 2.8 GB   | Downloading...          |\n'

# %%
import os
import pandas as pd

# Verify current working directory
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: d:\_edd\_local_repos\cs513_data_mining\trendy-tube

# %%
#FILE_NAME = '_raw_df_channels'
#FILE_NAME = '_raw_df_timeseries'
#FILE_NAME = 'df_channels_en'
#FILE_NAME = 'df_timeseries_en'
#FILE_NAME = 'num_comments'
FILE_NAME = 'num_comments_authors'
PATH = f'../RawData/{FILE_NAME}' + '.tsv.gz'

# Read and display the first few rows
SAMPLE_SIZE = 50_000 # target sample size
CHUNK_SIZE = 1_000_000 # chunk size for reading large files (do not read all into memory)
df = pd.read_csv(PATH, sep='\t', compression='gzip', nrows=CHUNK_SIZE)
df.head()
# Out:
#    author  video_id
# 0       1         5
# 1       2         3
# 2       3         2
# 3       4         6
# 4       5         3

# %%
# Display column information
print("\nDataFrame Info:")
df.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   author    1000000 non-null  int64
#  1   video_id  1000000 non-null  int64
# dtypes: int64(2)
# memory usage: 15.3 MB

# %%
# Sample some of the rows from the chunked dataframe
df_sample = df.sample(n=SAMPLE_SIZE, random_state=42).reset_index(drop=True)
print(f"Sampled dataset shape: {df_sample.shape}")
df_sample.head()
# Out:
# Sampled dataset shape: (50000, 2)
#     author  video_id
# 0  1269109         1
# 1   102809         1
# 2   728866         1
# 3   643685         3
# 4    71366        15

# %%
# Write to .csv file
df_sample.to_csv(f'../SampleData/{FILE_NAME}' + '_sample.csv', index=False)
